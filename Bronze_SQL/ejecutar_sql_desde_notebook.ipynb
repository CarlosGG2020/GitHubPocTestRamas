# %%
#path_sql = "/Workspace/Users/softguiraudand@gmail.com/select_1000.sql" ok
path_sql = "../../select_1000.sql"# ok forma relativa.. ok

with open(path_sql, "r", encoding="utf-8") as f:
    sql = f.read()

df=spark.sql(sql)
display(df)
